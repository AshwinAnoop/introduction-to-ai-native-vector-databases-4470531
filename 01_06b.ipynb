# %% [markdown]
# Given 3D vectors [40,120,60] and [60,50,90]

# %% [markdown]
# ### Q1 draw out these vectors

# %%
import numpy as np
import matplotlib.pyplot as plt

#Initialize the two vectors
colour1 = [40,120,60]
colour2 = [60,50,90]

# ADD CODE HERE

ax = plt.figure().add_subplot(projection='3d')

ax.scatter( xs = colour1[0] , ys = colour1[1] , zs = colour1[2] , label='colour1' )
ax.scatter( xs = colour2[0] , ys = colour2[1] , zs = colour2[2] , label='colour2' )
ax.scatter( 0 , 0 , 0 , label='origin')

# Draw out the vectors

ax.quiver(0,0,0,colour1[0],colour1[1],colour1[2])
ax.quiver(0,0,0,colour2[0],colour2[1],colour2[2])

# ADD CODE HERE


# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 150)
ax.set_ylim(0, 150)
ax.set_zlim(0, 150)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### Q2 Calculate the euclidian, manhattan, cosine, and dot product distances between these vectors

# %% [markdown]
# ### Manhattan distance

# %%
#my method

manhattan_distance = np.abs(np.array(colour1) - np.array(colour2)).sum()
print(manhattan_distance)
# Out:
# 120

# %%
L1 = # ADD CODE HERE

print(L1)

# %%
#An alternate approach

a = np.array(colour1)
b = np.array(colour2)

np.linalg.norm((a - b), ord=1)
# Out:
# np.float64(120.0)

# %% [markdown]
# ### Euclidian distance

# %%
#my code
abs_array = np.abs(a-b)
sumofsq = 0
for i in range(3):
    sumofsq += abs_array[i]**2
np.sqrt(sumofsq)
# Out:
# np.float64(78.74007874011811)

# %%
L2 = # ADD CODE HERE

print(L2)

# %%
np.linalg.norm((a - b), ord=2)

# %% [markdown]
# ### Cosine distance

# %%
cosine = np.dot(a,b)/ (np.linalg.norm(a)*np.linalg.norm(b))


print(cosine)
# Out:
# 0.8271930531781648

# %% [markdown]
# ### Dot product

# %%
dot = np.dot(a,b)

print(dot)
# Out:
# 13800

# %%
#alternate method

np.dot(a,b)

# %% [markdown]
# ---

# %% [markdown]
# ### Q3 Can you come up with a colour that has a smaller cosine distance from the first vector?

# %%
colour1 = [40,120,60]
colour2 = [60,50,90]

colour3 = # ADD CODE HERE

# %%
ax = plt.figure().add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
ax.scatter(xs=colour1[0], ys=colour1[1], zs=colour1[2], zdir='z', label='Colour1')

ax.scatter(xs=colour2[0], ys=colour2[1], zs=colour2[2], zdir='z', label='Colour2')

ax.scatter(0, 0, 0, zdir='z', label='Origin', c='black')

ax.quiver(0,0,0,colour1[0],colour1[1],colour1[2], color='black', arrow_length_ratio=0.1)
ax.quiver(0,0,0,colour2[0],colour2[1],colour2[2], color='black', arrow_length_ratio=0.1)

#Add vector 3 to the diagram

# ADD CODE HERE

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 150)
ax.set_ylim(0, 150)
ax.set_zlim(0, 150)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()
